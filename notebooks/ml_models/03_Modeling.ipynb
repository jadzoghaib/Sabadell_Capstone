# %% [markdown]
# # 03 — Model Building
#
# Binary classification to predict loan default.
#
# **Models:** Logistic Regression (baseline), XGBoost (Optuna-tuned), ANN
#
# **Primary metric:** ROC-AUC

# %% [markdown]
# ## Setup

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import (
    accuracy_score, confusion_matrix, classification_report,
    roc_auc_score, precision_score, recall_score, f1_score, roc_curve
)
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
import optuna

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC

optuna.logging.set_verbosity(optuna.logging.WARNING)

# %% [markdown]
# ## Data

# %%
processed = np.load("../../data/processed/02_processed_data.npz")
X_train = processed['X_train']
X_val   = processed['X_val']
X_test  = processed['X_test']
y_train = processed['y_train']
y_val   = processed['y_val']
y_test  = processed['y_test']

print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
print(f"X_val:   {X_val.shape},   y_val:   {y_val.shape}")
print(f"X_test:  {X_test.shape},  y_test:  {y_test.shape}")
# Out:
# X_train: (204126, 74), y_train: (204126,)
# X_val:   (51507, 74),   y_val:   (51507,)
# X_test:  (126845, 74),  y_test:  (126845,)

# %% [markdown]
# ## Helpers

# %%
def print_score(true, pred, train=True):
    clf_report = pd.DataFrame(classification_report(true, pred, output_dict=True))
    label = "Train" if train else "Test"
    print(f"{label} Result:")
    print("=" * 50)
    print(f"Accuracy Score: {accuracy_score(true, pred) * 100:.2f}%")
    print("_" * 50)
    print(f"CLASSIFICATION REPORT:\n{clf_report}")
    print("_" * 50)
    print(f"Confusion Matrix:\n{confusion_matrix(true, pred)}\n")

def find_best_threshold(y_true, probs):
    """Find threshold that maximizes F1 for the minority class (Charged Off = 0)."""
    fpr, tpr, thresholds = roc_curve(y_true, probs)
    recall_co = 1 - fpr
    n_co = (y_true == 0).sum()
    n_fp = (y_true == 1).sum()
    tp_co = recall_co * n_co
    fp_co = (1 - tpr) * n_fp
    precision_co = tp_co / (tp_co + fp_co + 1e-8)
    f1_co = 2 * (precision_co * recall_co) / (precision_co + recall_co + 1e-8)
    best_idx = np.argmax(f1_co)
    return thresholds[best_idx], precision_co[best_idx], recall_co[best_idx], f1_co[best_idx]

def evaluate_model(name, y_true, probs, threshold=None):
    if threshold is None:
        threshold, prec, rec, f1 = find_best_threshold(y_true, probs)
    preds = (probs >= threshold).astype(int)
    return {
        'model': name,
        'roc_auc_test': roc_auc_score(y_true, probs),
        'accuracy_test': accuracy_score(y_true, preds),
        'precision_co': precision_score(y_true, preds, pos_label=0, zero_division=0),
        'recall_co': recall_score(y_true, preds, pos_label=0, zero_division=0),
        'f1_co': f1_score(y_true, preds, pos_label=0, zero_division=0),
        'threshold': threshold,
    }

def plot_learning_evolution(r):
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    axes[0].plot(r.history['loss'],     label='Loss')
    axes[0].plot(r.history['val_loss'], label='val_Loss')
    axes[0].set_title('Loss Evolution During Training')
    axes[0].legend()
    axes[1].plot(r.history['AUC'],     label='AUC')
    axes[1].plot(r.history['val_AUC'], label='val_AUC')
    axes[1].set_title('AUC Score Evolution During Training')
    axes[1].legend()
    plt.tight_layout()
    plt.show()

# Class weights for imbalance handling.
n_pos = (y_train == 1).sum()  # Fully Paid (majority)
n_neg = (y_train == 0).sum()  # Charged Off (minority)

# XGBoost docs recommend `sum(neg)/sum(pos)` for scale_pos_weight. Because
# the positive class is the majority here, this value is < 1 — it
# downweights the majority so XGBoost focuses on catching defaults.
# (The previous code had this inverted and was actively biasing predictions
# toward Fully Paid.)
scale_pos_weight = n_neg / n_pos
print(f"scale_pos_weight (n_neg / n_pos): {scale_pos_weight:.4f}")
print(f"Charged Off rate (train): {n_neg / len(y_train) * 100:.1f}%")
# Out:
# scale_pos_weight (n_neg / n_pos): 0.2053
# Charged Off rate (train): 17.0%

# %%
lr_model = LogisticRegression(
    class_weight='balanced', max_iter=1000, random_state=42
)
lr_model.fit(X_train, y_train)

# Pick the F1-optimal threshold on val, then evaluate on test at that fixed threshold.
lr_val_probs  = lr_model.predict_proba(X_val)[:, 1]
lr_threshold, _, _, _ = find_best_threshold(y_val, lr_val_probs)

lr_test_probs = lr_model.predict_proba(X_test)[:, 1]
lr_metrics = evaluate_model('Logistic Regression', y_test, lr_test_probs,
                            threshold=lr_threshold)
lr_probs = lr_test_probs  # alias for ROC plot below

print(f"ROC-AUC (test): {lr_metrics['roc_auc_test']:.4f}")
print(f"Threshold (from val): {lr_metrics['threshold']:.3f}")
print(f"Charged Off — Precision: {lr_metrics['precision_co']:.3f}, "
      f"Recall: {lr_metrics['recall_co']:.3f}, F1: {lr_metrics['f1_co']:.3f}")
print()
preds = (lr_test_probs >= lr_threshold).astype(int)
print_score(y_test, preds, train=False)
# Out:
# ROC-AUC (test): 0.7075
# Threshold (from val): 0.466
# Charged Off — Precision: 0.291, Recall: 0.593, F1: 0.390
#
# Test Result:
# ...
# Accuracy Score: 68.46%
# __________________________________________________
# CLASSIFICATION REPORT:
#                     0.0            1.0  accuracy      macro avg   weighted avg
# precision      0.290595       0.893879  0.684631       0.592237       0.791257
# recall         0.592529       0.703509  0.684631       0.648019       0.684631
# f1-score       0.389947       0.787350  0.684631       0.588649       0.719750
# support    21577.000000  105268.000000  0.684631  126845.000000  126845.000000
# __________________________________________________
# Confusion Matrix:
# [[12785  8792]
#  [31211 74057]]

# %% [markdown]
# ## XGBoost (Optuna-tuned)

# %%
def xgb_objective(trial):
    params = {
        'n_estimators':     trial.suggest_int('n_estimators', 100, 500, step=50),
        'max_depth':        trial.suggest_int('max_depth', 3, 8),
        'learning_rate':    trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample':        trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'reg_alpha':        trial.suggest_float('reg_alpha', 1e-3, 10, log=True),
        'reg_lambda':       trial.suggest_float('reg_lambda', 1e-3, 10, log=True),
        'scale_pos_weight': scale_pos_weight,
        'eval_metric':      'auc',
        'random_state':     42,
        'n_jobs':           -1,
    }
    model = xgb.XGBClassifier(**params)
    # Score on VAL, not TEST. Test stays untouched until the final eval cell.
    model.fit(
        X_train, y_train,
        eval_set=[(X_val, y_val)],
        verbose=False,
    )
    probs = model.predict_proba(X_val)[:, 1]
    return roc_auc_score(y_val, probs)

study = optuna.create_study(direction='maximize')
study.optimize(xgb_objective, n_trials=50, show_progress_bar=True)

print(f"Best val ROC-AUC: {study.best_value:.4f}")
print(f"Best params: {study.best_params}")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best val ROC-AUC: 0.7112
# Best params: {'n_estimators': 500, 'max_depth': 4, 'learning_rate': 0.07152296153948827, 'subsample': 0.9896433119452019, 'colsample_bytree': 0.6929893005704691, 'min_child_weight': 5, 'reg_alpha': 5.57993662321347, 'reg_lambda': 0.1801308257282239}

# %%
# Train final XGBoost with best params from Optuna (selected against val).
best_params = study.best_params
best_params['scale_pos_weight'] = scale_pos_weight
best_params['eval_metric'] = 'auc'
best_params['random_state'] = 42
best_params['n_jobs'] = -1

xgb_model = xgb.XGBClassifier(**best_params)
xgb_model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=False)

# Pick threshold on val, then evaluate once on test at that fixed threshold.
xgb_val_probs  = xgb_model.predict_proba(X_val)[:, 1]
xgb_threshold, _, _, _ = find_best_threshold(y_val, xgb_val_probs)

xgb_test_probs = xgb_model.predict_proba(X_test)[:, 1]
xgb_metrics = evaluate_model('XGBoost', y_test, xgb_test_probs,
                             threshold=xgb_threshold)
xgb_probs = xgb_test_probs  # alias for ROC plot below

print(f"ROC-AUC (test): {xgb_metrics['roc_auc_test']:.4f}")
print(f"Threshold (from val): {xgb_metrics['threshold']:.3f}")
print(f"Charged Off — Precision: {xgb_metrics['precision_co']:.3f}, "
      f"Recall: {xgb_metrics['recall_co']:.3f}, F1: {xgb_metrics['f1_co']:.3f}")
print()
preds = (xgb_test_probs >= xgb_threshold).astype(int)
print_score(y_test, preds, train=False)
# Out:
# ROC-AUC (test): 0.7121
# Threshold (from val): 0.465
# Charged Off — Precision: 0.295, Recall: 0.591, F1: 0.393
#
# Test Result:
# ...
# Accuracy Score: 68.98%
# __________________________________________________
# CLASSIFICATION REPORT:
#                     0.0            1.0  accuracy      macro avg   weighted avg
# precision      0.294607       0.894334  0.689795       0.594470       0.792317
# recall         0.590675       0.710111  0.689795       0.650393       0.689795
# f1-score       0.393134       0.791646  0.689795       0.592390       0.723857
# support    21577.000000  105268.000000  0.689795  126845.000000  126845.000000
# __________________________________________________
# Confusion Matrix:
# [[12745  8832]
#  [30516 74752]]

# %%
def nn_model(num_columns, num_labels, hidden_units, dropout_rates, learning_rate):
    inp = Input(shape=(num_columns,))
    x = BatchNormalization()(inp)
    x = Dropout(dropout_rates[0])(x)
    for i in range(len(hidden_units)):
        x = Dense(hidden_units[i], activation='relu')(x)
        x = BatchNormalization()(x)
        x = Dropout(dropout_rates[i + 1])(x)
    x = Dense(num_labels, activation='sigmoid')(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(optimizer=Adam(learning_rate=learning_rate),
                  loss='binary_crossentropy',
                  metrics=[AUC(name='AUC')])
    return model

num_columns   = X_train.shape[1]
num_labels    = 1
hidden_units  = [256, 128, 64]
dropout_rates = [0.3, 0.3, 0.3, 0.2]
learning_rate = 1e-3

ann_model = nn_model(num_columns, num_labels, hidden_units, dropout_rates, learning_rate)

class_weight = {0: len(y_train) / (2 * n_neg), 1: len(y_train) / (2 * n_pos)}
print(f"Class weights: {class_weight}")

# Early stopping monitors VAL AUC, not TEST AUC. Previously this leaked the
# test set into model selection (restore_best_weights would pick the epoch
# with peak test AUC).
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_AUC', mode='max', patience=5, restore_best_weights=True
)

r = ann_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=512,
    class_weight=class_weight,
    callbacks=[early_stop]
)
# Out:
# Class weights: {0: np.float64(2.9359664010585966), 1: np.float64(0.6026286733229809)}
# Epoch 1/50
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - AUC: 0.6398 - loss: 0.6858 - val_AUC: 0.6990 - val_loss: 0.6316
# Epoch 2/50
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - AUC: 0.6821 - loss: 0.6424 - val_AUC: 0.7039 - val_loss: 0.6253
# Epoch 3/50
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - AUC: 0.6886 - loss: 0.6374 - val_AUC: 0.7043 - val_loss: 0.6168
# Epoch 4/50
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - AUC: 0.6916 - loss: 0.6355 - val_AUC: 0.7050 - val_loss: 0.6232
# Epoch 5/50
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - AUC: 0.6916 - loss: 0.6353 - val_AUC: 0.7059 - val_loss: 0.6241
# Epoch 6/50
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - AUC: 0.6933 - loss: 0.6341 - val_AUC: 0.7050 - val_loss: 0.6214
# Epoch 7/50
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - AUC: 0.6949 - loss: 0.6330 - val_AUC: 0.7059 - val_loss: 0.6218
# Epoch 8/50
# ...

# %% [markdown]
# ## Artificial Neural Network (ANN)
#
# > Currently disabled. Uncomment cells below to re-enable.

# %%
plot_learning_evolution(r)

# %%
# Pick threshold on val, then evaluate on test at that fixed threshold.
ann_val_probs  = ann_model.predict(X_val,  verbose=0).ravel()
ann_threshold, _, _, _ = find_best_threshold(y_val, ann_val_probs)

ann_test_probs = ann_model.predict(X_test, verbose=0).ravel()
ann_metrics = evaluate_model('ANN', y_test, ann_test_probs,
                             threshold=ann_threshold)
ann_probs = ann_test_probs  # alias for ROC plot below

print(f"ROC-AUC (test): {ann_metrics['roc_auc_test']:.4f}")
print(f"Threshold (from val): {ann_metrics['threshold']:.3f}")
print(f"Charged Off — Precision: {ann_metrics['precision_co']:.3f}, "
      f"Recall: {ann_metrics['recall_co']:.3f}, F1: {ann_metrics['f1_co']:.3f}")
print()
preds = (ann_test_probs >= ann_threshold).astype(int)
print_score(y_test, preds, train=False)
# Out:
# ROC-AUC (test): 0.7087
# Threshold (from val): 0.468
# Charged Off — Precision: 0.286, Recall: 0.613, F1: 0.390
#
# Test Result:
# ...
# Accuracy Score: 67.40%
# __________________________________________________
# CLASSIFICATION REPORT:
#                     0.0            1.0  accuracy      macro avg   weighted avg
# precision      0.286061       0.896339  0.674027       0.591200       0.792528
# recall         0.612597       0.686619  0.674027       0.649608       0.674027
# f1-score       0.390004       0.777587  0.674027       0.583795       0.711657
# support    21577.000000  105268.000000  0.674027  126845.000000  126845.000000
# __________________________________________________
# Confusion Matrix:
# [[13218  8359]
#  [32989 72279]]

# %% [markdown]
# ## Model Comparison & Export

# %%
results = pd.DataFrame([lr_metrics, xgb_metrics, ann_metrics]).set_index('model')
print(results.to_string())
print(f"\nBest model by ROC-AUC: {results['roc_auc_test'].idxmax()}")

# ROC curves
plt.figure(figsize=(8, 6))
for name, probs in [('Logistic Regression', lr_probs), ('XGBoost', xgb_probs), ('ANN', ann_probs)]:
    fpr, tpr, _ = roc_curve(y_test, probs)
    auc = roc_auc_score(y_test, probs)
    plt.plot(fpr, tpr, label=f'{name} (AUC={auc:.3f})')
plt.plot([0, 1], [0, 1], 'k--', alpha=0.3)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves — Model Comparison')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#                      roc_auc_test  accuracy_test  precision_co  recall_co     f1_co  threshold
# model
# Logistic Regression      0.707500       0.684631      0.290595   0.592529  0.389947   0.466353
# XGBoost                  0.712129       0.689795      0.294607   0.590675  0.393134   0.465402
# ANN                      0.708690       0.674027      0.286061   0.612597  0.390004   0.468440
#
# Best model by ROC-AUC: XGBoost

# %%
os.makedirs('../../models', exist_ok=True)
os.makedirs('../../data/results/ml', exist_ok=True)

joblib.dump(lr_model, '../../models/lr_model.joblib')
joblib.dump(xgb_model, '../../models/xgb_model.joblib')
ann_model.save('../../models/ann_model.keras')

thresholds = {
    'lr':  lr_metrics['threshold'],
    'xgb': xgb_metrics['threshold'],
    'ann': ann_metrics['threshold'],
}
joblib.dump(thresholds, '../../models/thresholds.joblib')

results.to_csv('../../data/results/ml/03_model_performance.csv')

print("Models saved to ../../models/")
print("Performance saved to ../../data/results/ml/03_model_performance.csv")
# Out:
# Models saved to ../../models/
# Performance saved to ../../data/results/ml/03_model_performance.csv
